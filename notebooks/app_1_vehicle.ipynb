# %%
import sys
sys.path.append('../src')
import solvers as solvers
import importlib
import generator
importlib.reload(solvers)
importlib.reload(generator)
# Out:
# <module 'generator' from '/home/mezcla/Documents/SmartRouteVRP/notebooks/../src/generator.py'>

# %%
data = generator.create_data_model_one_vehicle()

# %%
manager, routing, solution = solvers.omdrm_one_vehicle(data)
# Out:
# Create the routing index manager
# Create Routing Model
# Create and register a transit callback
# Print solution
# Route for vehicle 0:
#  0 -> 1 -> 4 -> 3 -> 2 -> 0
# Distance of the route: 24m
#
# Maximum of the route distances: 24m
